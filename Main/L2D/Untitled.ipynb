# %%
# %run PPO_jssp_multiInstances.py
# Out:
# Original entropy coef: 0.05
# New entropy coef: 0.2
# /Users/nhi/Capstone_scshinkwaii-Claude/L2D/mb_agg.py:44: UserWarning: torch.sparse.SparseTensor(indices, values, shape, *, device=) is deprecated.  Please use torch.sparse_coo_tensor(indices, values, shape, dtype=, device=). (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/torch/csrc/utils/tensor_new.cpp:620.)
#   graph_pool = torch.sparse.FloatTensor(idx, elem,
# Ep   10 | Reward: -566.00 | VLoss: 1.017489 | Temp: 10.00
# Ep   20 | Reward: -498.50 | VLoss: 0.461246 | Temp: 10.00
# Ep   30 | Reward: -550.75 | VLoss: 0.345932 | Temp: 10.00
# Ep   40 | Reward: -485.75 | VLoss: 0.372811 | Temp: 10.00
# Ep   50 | Reward: -558.25 | VLoss: 0.398471 | Temp: 10.00
#   Policy: MaxProb=0.149, Entropy=2.072/2.08
# Ep   60 | Reward: -530.50 | VLoss: 0.291458 | Temp: 10.00
# Ep   70 | Reward: -529.75 | VLoss: 0.269132 | Temp: 10.00
# Ep   80 | Reward: -487.75 | VLoss: 0.503128 | Temp: 10.00
# ...
